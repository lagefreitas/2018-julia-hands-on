# %% [markdown]
# # <center><span style="color:red">Introduction to Julia for Scientists</span></center>
#
# <center>**[André Lage-Freitas](http://lattes.cnpq.br/3203407648310274) and [Charles Santana](http://lattes.cnpq.br/0342795948350883)**</center>
# <center>lage@laccan.ufal.br, charlesn@ethz.ch</center>
#
#
# <center>**70th Annual Meeting of the Brazilian Society for the Progress of Science (SBPC) 2018**</center>
#
# <center>_70a. Reunião Anual da Sociedade Brasileira para o Progresso da Ciência (SBPC) 2018_</center>
#
# <center>July, 2018</center>
# <center>Maceió, Brazil</center>
#
# <a data-flickr-embed="true"  href="http://ra.sbpcnet.org.br/maceio/" title="70a. RA SBPC 2018"><img src="https://farm9.staticflickr.com/8316/8039204779_6eff98a64c_z.jpg" width="640" height="179" alt="Maré No Osso"></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# <a href="http://ufal.br"><img src="figures/logo-ufal-laccan-banner.svg" width="220" alt="LaCCAN-UFAL"></a>
# <a href="http://ethz.ch"><img src="figures/ethz.svg" width="120" alt="ETHZ"></a>
#
# ----
#
#
# # Contents
#
# 1. [**Introduction to Julia**](introduction.ipynb)
#     1. History of Julia Language and Julia Community
#     1. Types
#     1. Control Flow
#     1. Functions
#     1. Multidimensional Arrays
# 1. [**Introduction to Distributed Computing**](distributed_computing_with_julia.ipynb)
#     1. Master/Worker Architecture
#     1. Support for distributed communication
#     1. Tasks
#     1. Distributed Arrays
#     1. Distributed MapReduce
#     1. [CloudArray: Easy Big Data Programming in the Cloud](cloudarray.ipynb)
# 1. [**Data Analysis and Visualization**](data_analysis_visualization.ipynb)
#     1. Importing data
#     1. Basic statistical analysis
#     1. Scatter plots, Histograms, Visualization
# 1. [**Applications: Complex Systems, Ecology, Machine Learning**](applications.ipynb)
#     1. Data Classification
#     1. Linear Regression
#     1. Graph Theory
#     1. [Climate Science](https://github.com/Balinus/ClimateTools.jl)
#
# ---
#
# ## Acknowledgements
#
# ### About the authors
#
# Dr. **André Lage-Freitas** is an Assistant Professor of Universidade Federal de Alagoas (UFAL) and member of LaCCAN lab (Laboratório de Computação Científica e Análise Numérica). He also holds a Ph.D. in Computer Science from the _Institut National des Sciences Appliquées de Rennes_ (INRIA, France), a Master Degree in computer Science from the Universitée de Rennes 1 (France) and a Bachelor Degree in Computer Science from the Universidade Federal da Bahia (Brazil). The main research problem he is working on is how to ease the use of Cloud computing infrastructures for Data Science applications by focusing on big remote sensing data sets. Dr. André Lage-Freitas has experience in international research projects such as CloudArray project (coordinator) funded by Microsoft Azure Research and further international projects funded by European Union and Latin America, e.g., [EOxposure H2020](http://www.h2020-eoxposure.eu), [S-CUBE FP7](http://www.s-cube-network.eu), [CONICYT](http://www.conicyt.cl) (Chile), and [FAPEAL](http://www.fapeal.br) (Brazil). He reviews research projects for [FAPESP](http://www.fapesp.br) (São Paulo Research Foundation) and he is a reviewer of the [IEEE Geoscience and Remote Sensing Letters journal](). He held for two years the Research Coordinator position under the UFAL Vice-Presidency of Research and Graduate Course. He is member of the [IEEE](https://www.ieee.org) and of the [SBC](http://sbc.org.br) (Sociedade Brasileira de Computação). He is Counsellor of [IEEE-UFAL Student Branch](http://sites.ieee.org/sb-ufal/) and [Enactus UFAL](http://enactus.org).
#
#
# **Charles Novaes de Santana** is a Computer Scientist with experience in Computer Modeling using concepts of Artificial Inteligence and Complex Systems to answer to Interdisciplinary questions. He holds a PhD in Climate Change by the University Menéndez Pelayo (Spain, 2013), a MsC in Climate change by the same university (2009) and a MsC in Environmental Sciences by the Universidade Estadual de Feira de Santana (Brazil, 2007). During last 5 years he has been working as Postdoctoral Researcher at different institutions in Switzerland (Eawag, UZH, ETH) and in Brazil (UEFS) as well as he has dedicated time to create a technological-based company with focus in Data Science: [DataSCOUT - Data Science and sCientific COmpUting](http://www.datascout.com.br). He has used Julia in different scientific projects in Ecology and in Complex Systems. Currently, his main research topic is the evolution of biodiversity in changing landscapes, using paleo-climatic reconstruction to understand biodiversity dynamics and climate forecast to understand the effects of climate change in this biodiversity. When he is not playing god with a computer and datasets, he is enjoying life with his beautiful daughter and wife. "La vida son dos días".
#
#
# ### Disclaimer
#
# This material has **no intention to replace any other material on Julia**  (book, tutorial, manual, documentation, etc.). The main goal is to provide another means to learn Julia.
#
# The IJulia Notebooks are mainly based on the following materials:
#
# 1. [Introduction to Julia for Distributed Computing](https://github.com/proflage/2015-julia-hands-on)
# 1. [Hands-on | David Sanders](https://github.com/dpsanders/hands_on_julia)
# 1. [Julia Official Documentation](http://docs.julialang.org/en/latest/manual)
# 1. Bezanson et al. [Julia: A Fresh Approach to Numerical Computing](http://arxiv.org/abs/1411.1607). arXiv paper, 2015.
# 1. Balbaert, Ivo. _Getting Started with Julia Programming_. Packt Publishing Ltd. ISBN 978-78328-479-5. 2015.
# 1. Wikibooks contributors, _Introducing Julia/Modules and packages_. Wikibooks, The Free Textbook Project. [Link.](http://en.wikibooks.org/w/index.php?title=Introducing_Julia/Modules_and_packages&oldid=2963219) (accessed May 30, 2015).
# 1. [Parallel and Distributed Computing with Julia (Jeff Bezanson)](https://www.youtube.com/watch?v=JoRn4ryMclc)
# 1. Discussions in Julia Discourse Community [https://discourse.julialang.org/c/domain/stats]
#
#
# ### License
#
# Feel free to use it under the terms of the [Creative Commons BY-SA](http://creativecommons.org/licenses/by-sa/4.0/).
